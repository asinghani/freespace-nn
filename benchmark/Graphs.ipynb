# %%
import cv2
import numpy as np
import matplotlib
# %matplotlib inline
import matplotlib.pyplot as plt
import scipy as sp
import pandas as pd

# %%
# Load data
data = pd.read_csv("/Users/anish/Downloads/log.csv")

# %%
plt.plot(data["epoch"], data["val_mean_iou"])
plt.plot(data["epoch"], data["mean_iou"])

# %%
plt.plot(data["epoch"], data["val_acc"])
plt.plot(data["epoch"], data["acc"])

# %%
plt.plot(data["epoch"], data["val_loss"])
plt.plot(data["epoch"], data["loss"])
